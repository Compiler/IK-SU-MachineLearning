# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', 84)
pd.set_option('display.max_rows', 84)

# %%
df = pd.read_csv('data/2022/survey_results_public.csv')
schema_df = pd.read_csv('data/2022/survey_results_schema.csv', index_col ='qname')

# %%
df.head()
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                                      None of these
# 1           2                     I am a developer by profession
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#             Employment                            RemoteWork  \
# 0                  NaN                                   NaN
# 1  Employed, full-time                          Fully remote
# 2  Employed, full-time  Hybrid (some remote, some in-person)
# 3  Employed, full-time                          Fully remote
# 4  Employed, full-time  Hybrid (some remote, some in-person)
#
#                            CodingActivities  \
# 0                                       NaN
# 1  Hobby;Contribute to open-source projects
# 2                                     Hobby
# ...

# %%
schema_df
# Out:
#                          qid  \
# qname
# S0                     QID16
# MetaInfo               QID12
# S1                      QID1
# MainBranch              QID2
# Employment            QID296
# RemoteWork            QID308
# CodingActivities      QID297
# S2                    QID190
# EdLevel                QID25
# LearnCode             QID276
# LearnCodeOnline       QID281
# LearnCodeCoursesCert  QID306
# YearsCode              QID32
# YearsCodePro           QID34
# DevType                QID31
# OrgSize                QID29
# PurchaseInfluence     QID278
# BuyNewTool            QID279
# Country                 QID6
# Currency               QID50
# CompTotal              QID51
# CompFreq               QID52
# S3                     QID61
# Language              QID233
# Database              QID262
# Platform              QID263
# Webframe              QID264
# MiscTech              QID265
# ToolsTech             QID275
# NEWCollabTools        QID274
# ...

# %%
df[['MainBranch','CodingActivities']]
# Out:
#                                               MainBranch  \
# 0                                          None of these
# 1                         I am a developer by profession
# 2      I am not primarily a developer, but I write co...
# 3                         I am a developer by profession
# 4                         I am a developer by profession
# ...                                                  ...
# 73263                     I am a developer by profession
# 73264                     I am a developer by profession
# 73265  I am not primarily a developer, but I write co...
# 73266                     I am a developer by profession
# 73267  I used to be a developer by profession, but no...
#
#                                         CodingActivities
# 0                                                    NaN
# 1               Hobby;Contribute to open-source projects
# 2                                                  Hobby
# ...

# %%
df['MainBranch'].value_counts()
# Out:
# I am a developer by profession                                                   53507
# I am learning to code                                                             6309
# I am not primarily a developer, but I write code sometimes as part of my work     5794
# I code primarily as a hobby                                                       4865
# None of these                                                                     1497
# I used to be a developer by profession, but no longer am                          1296
# Name: MainBranch, dtype: int64

# %%
df.loc[40:50, ['Age','EdLevel','MainBranch','ConvertedCompYearly']]
# Out:
#                 Age                                            EdLevel  \
# 40  35-44 years old                Associate degree (A.A., A.S., etc.)
# 41  18-24 years old  Secondary school (e.g. American high school, G...
# 42  25-34 years old       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 43  35-44 years old  Some college/university study without earning ...
# 44  18-24 years old  Secondary school (e.g. American high school, G...
# 45  25-34 years old    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 46  18-24 years old  Secondary school (e.g. American high school, G...
# 47  25-34 years old       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 48  55-64 years old  Some college/university study without earning ...
# 49  25-34 years old  Secondary school (e.g. American high school, G...
# 50  25-34 years old    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                            MainBranch  ConvertedCompYearly
# ...

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'BuyNewTool', 'Country', 'Currency',
#        'CompTotal', 'CompFreq', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysProfessional use',
#        'OpSysPersonal use', 'VersionControlSystem', 'VCInteraction',
#        'VCHostingPersonal use', 'VCHostingProfessional use',
#        'OfficeStackAsyncHaveWorkedWith', 'OfficeStackAsyncWantToWorkWith',
# ...

# %%
schema_df.loc['CompTotal', 'question']
# Out:
# 'What is your current total compensation (salary, bonuses, and perks, before taxes and deductions)? Please enter a whole number in the box below, without any punctuation.  If you are paid hourly, please estimate an equivalent weekly, monthly, or yearly salary. If you prefer not to answer, please leave the box empty.'

# %%
schema_df.loc['Trans', 'question']
# Out:
# 'Do you identify as transgender?'

# %%
schema_df.loc['Sexuality', 'question']
# Out:
# 'Which of the following describe you, if any? Please check all that apply.'

# %%
schema_df.loc['Gender', 'question']
# Out:
# 'Which of the following describe you, if any? Please check all that apply.'

# %%
schema_df.loc['Ethnicity', 'question']
# Out:
# 'Which of the following describe you, if any? Please check all that apply.'

# %%
rich_pro_devs = df[(df['MainBranch'] == "I am a developer by profession") & (df['ConvertedCompYearly'] > 1000000)]
print("there are",rich_pro_devs.shape[0],'rich developers')
# Out:
# there are 778 rich developers

# %%
df['Sexuality'].unique()
# Out:
# array([nan, 'Bisexual', 'Straight / Heterosexual',
#        'Prefer to self-describe:', 'Bisexual;Straight / Heterosexual',
#        'Gay or Lesbian', 'Prefer to self-describe:;Queer',
#        'Prefer not to say', 'Queer', 'Straight / Heterosexual;Queer',
#        'Straight / Heterosexual;Prefer to self-describe:',
#        'Bisexual;Queer', 'Bisexual;Gay or Lesbian',
#        'Gay or Lesbian;Queer',
#        'Bisexual;Straight / Heterosexual;Prefer to self-describe:;Queer',
#        'Bisexual;Prefer to self-describe:',
#        'Prefer to self-describe:;Gay or Lesbian;Queer',
#        'Straight / Heterosexual;Prefer to self-describe:;Queer',
#        'Bisexual;Straight / Heterosexual;Gay or Lesbian',
#        'Bisexual;Straight / Heterosexual;Prefer to self-describe:;Gay or Lesbian;Queer',
#        'Bisexual;Straight / Heterosexual;Queer',
#        'Bisexual;Gay or Lesbian;Queer',
#        'Bisexual;Prefer to self-describe:;Queer',
# ...

# %%
rich_pro_devs = rich_pro_devs[~rich_pro_devs['Sexuality'].isnull()]

# %%
rich_pro_devs['Sexuality'].unique()
# Out:
# array(['Straight / Heterosexual', 'Bisexual', 'Prefer not to say',
#        'Gay or Lesbian', 'Queer',
#        'Straight / Heterosexual;Prefer to self-describe:',
#        'Bisexual;Queer', 'Gay or Lesbian;Queer',
#        'Prefer to self-describe:', 'Bisexual;Straight / Heterosexual',
#        'Bisexual;Prefer to self-describe:;Queer',
#        'Straight / Heterosexual;Queer'], dtype=object)

# %%
str8_devs = rich_pro_devs[(rich_pro_devs['Sexuality'] == 'Straight / Heterosexual') |(rich_pro_devs['Sexuality'] == 'Prefer not to say')]
print(str8_devs.shape[0])
# Out:
# 692

# %%
print(rich_pro_devs.shape[0])
# Out:
# 759

# %%
rich_filter = (df['MainBranch'] == "I am a developer by profession") & (df['ConvertedCompYearly'] > 1000000)
usa_filter = df['Country'].isin(['United States of America'])
lang_filter = df['LanguageHaveWorkedWith'].str.contains('C++', regex=False)
df.loc[rich_filter & usa_filter & lang_filter, ['Country', 'LanguageHaveWorkedWith', 'ConvertedCompYearly']]
# Out:
#                         Country  \
# 514    United States of America
# 558    United States of America
# 1382   United States of America
# 1463   United States of America
# 1823   United States of America
# 1841   United States of America
# 1888   United States of America
# 1939   United States of America
# 2274   United States of America
# 2706   United States of America
# 2901   United States of America
# 3002   United States of America
# 3024   United States of America
# 3270   United States of America
# 3562   United States of America
# 7852   United States of America
# 9417   United States of America
# 11964  United States of America
# 13146  United States of America
# 13230  United States of America
# 13242  United States of America
# 13495  United States of America
# 14882  United States of America
# 15855  United States of America
# 15930  United States of America
# 16015  United States of America
# 20249  United States of America
# 20456  United States of America
# ...
