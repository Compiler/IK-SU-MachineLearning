# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', 84)
pd.set_option('display.max_rows', 84)

# %%
df = pd.read_csv('data/2022/survey_results_public.csv')
schema_df = pd.read_csv('data/2022/survey_results_schema.csv', index_col ='qname')

# %%
df.head()
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                                      None of these
# 1           2                     I am a developer by profession
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#             Employment                            RemoteWork  \
# 0                  NaN                                   NaN
# 1  Employed, full-time                          Fully remote
# 2  Employed, full-time  Hybrid (some remote, some in-person)
# 3  Employed, full-time                          Fully remote
# 4  Employed, full-time  Hybrid (some remote, some in-person)
#
#                            CodingActivities  \
# 0                                       NaN
# 1  Hobby;Contribute to open-source projects
# 2                                     Hobby
# 3              I don’t code outside of work
# 4                                     Hobby
#
#                                            EdLevel  \
# 0                                              NaN
# 1                                              NaN
# 2  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                            LearnCode  \
# 0                                                NaN
# 1                                                NaN
# 2  Books / Physical media;Friend or family member...
# 3  Books / Physical media;School (i.e., Universit...
# 4  Other online resources (e.g., videos, blogs, f...
#
#                                      LearnCodeOnline LearnCodeCoursesCert  \
# 0                                                NaN                  NaN
# 1                                                NaN                  NaN
# 2  Technical documentation;Blogs;Programming Game...                  NaN
# 3                                                NaN                  NaN
# 4  Technical documentation;Blogs;Stack Overflow;O...                  NaN
#
#   YearsCode YearsCodePro                                            DevType  \
# 0       NaN          NaN                                                NaN
# 1       NaN          NaN                                                NaN
# 2        14            5  Data scientist or machine learning specialist;...
# 3        20           17                              Developer, full-stack
# 4         8            3  Developer, front-end;Developer, full-stack;Dev...
#
#                 OrgSize      PurchaseInfluence  \
# 0                   NaN                    NaN
# 1                   NaN                    NaN
# 2    20 to 99 employees  I have some influence
# 3  100 to 499 employees  I have some influence
# 4    20 to 99 employees  I have some influence
#
#                                           BuyNewTool  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                            Other (please specify):
# 4  Start a free trial;Visit developer communities...
#
#                                              Country  \
# 0                                                NaN
# 1                                             Canada
# 2  United Kingdom of Great Britain and Northern I...
# 3                                             Israel
# 4                           United States of America
#
#                     Currency  CompTotal CompFreq  \
# 0                        NaN        NaN      NaN
# 1       CAD\tCanadian dollar        NaN      NaN
# 2        GBP\tPound sterling    32000.0   Yearly
# 3    ILS\tIsraeli new shekel    60000.0  Monthly
# 4  USD\tUnited States dollar        NaN      NaN
#
#                         LanguageHaveWorkedWith  \
# 0                                          NaN
# 1                        JavaScript;TypeScript
# 2            C#;C++;HTML/CSS;JavaScript;Python
# 3                 C#;JavaScript;SQL;TypeScript
# 4  C#;HTML/CSS;JavaScript;SQL;Swift;TypeScript
#
#                        LanguageWantToWorkWith  \
# 0                                         NaN
# 1                             Rust;TypeScript
# 2       C#;C++;HTML/CSS;JavaScript;TypeScript
# 3                           C#;SQL;TypeScript
# 4  C#;Elixir;F#;Go;JavaScript;Rust;TypeScript
#
#                               DatabaseHaveWorkedWith  \
# 0                                                NaN
# 1                                                NaN
# 2                               Microsoft SQL Server
# 3                               Microsoft SQL Server
# 4  Cloud Firestore;Elasticsearch;Microsoft SQL Se...
#
#                               DatabaseWantToWorkWith  \
# 0                                                NaN
# 1                                                NaN
# 2                               Microsoft SQL Server
# 3                               Microsoft SQL Server
# 4  Cloud Firestore;Elasticsearch;Firebase Realtim...
#
#      PlatformHaveWorkedWith    PlatformWantToWorkWith  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                       NaN                       NaN
# 4  Firebase;Microsoft Azure  Firebase;Microsoft Azure
#
#                          WebframeHaveWorkedWith  \
# 0                                           NaN
# 1                                           NaN
# 2                                    Angular.js
# 3                         ASP.NET;ASP.NET Core
# 4  Angular;ASP.NET;ASP.NET Core ;jQuery;Node.js
#
#                  WebframeWantToWorkWith MiscTechHaveWorkedWith  \
# 0                                   NaN                    NaN
# 1                                   NaN                    NaN
# 2                    Angular;Angular.js                 Pandas
# 3                 ASP.NET;ASP.NET Core                    .NET
# 4  Angular;ASP.NET Core ;Blazor;Node.js                   .NET
#
#   MiscTechWantToWorkWith ToolsTechHaveWorkedWith ToolsTechWantToWorkWith  \
# 0                    NaN                     NaN                     NaN
# 1                    NaN                     NaN                     NaN
# 2                   .NET                     NaN                     NaN
# 3                   .NET                     NaN                     NaN
# 4      .NET;Apache Kafka                     npm       Docker;Kubernetes
#
#                        NEWCollabToolsHaveWorkedWith  \
# 0                                               NaN
# 1                                               NaN
# 2                           Notepad++;Visual Studio
# 3        Notepad++;Visual Studio;Visual Studio Code
# 4  Notepad++;Visual Studio;Visual Studio Code;Xcode
#
#                  NEWCollabToolsWantToWorkWith OpSysProfessional use  \
# 0                                         NaN                   NaN
# 1                                         NaN                 macOS
# 2                     Notepad++;Visual Studio               Windows
# 3  Notepad++;Visual Studio;Visual Studio Code               Windows
# 4      Rider;Visual Studio;Visual Studio Code               Windows
#
#                    OpSysPersonal use         VersionControlSystem  \
# 0                                NaN                          NaN
# 1  Windows Subsystem for Linux (WSL)                          Git
# 2                            Windows                          Git
# 3                            Windows                          Git
# 4                      macOS;Windows  Git;Other (please specify):
#
#                                        VCInteraction  VCHostingPersonal use  \
# 0                                                NaN                    NaN
# 1                                                NaN                    NaN
# 2                                        Code editor                    NaN
# 3  Code editor;Command-line;Version control hosti...                    NaN
# 4                                        Code editor                    NaN
#
#    VCHostingProfessional use OfficeStackAsyncHaveWorkedWith  \
# 0                        NaN                            NaN
# 1                        NaN                            NaN
# 2                        NaN                            NaN
# 3                        NaN    Jira Work Management;Trello
# 4                        NaN                            NaN
#
#   OfficeStackAsyncWantToWorkWith OfficeStackSyncHaveWorkedWith  \
# 0                            NaN                           NaN
# 1                            NaN                           NaN
# 2                            NaN               Microsoft Teams
# 3    Jira Work Management;Trello                    Slack;Zoom
# 4                            NaN          Microsoft Teams;Zoom
#
#   OfficeStackSyncWantToWorkWith        Blockchain  \
# 0                           NaN               NaN
# 1                           NaN  Very unfavorable
# 2               Microsoft Teams  Very unfavorable
# 3                    Slack;Zoom  Very unfavorable
# 4                           NaN       Unfavorable
#
#                                           NEWSOSites             SOVisitFreq  \
# 0                                                NaN                     NaN
# 1  Collectives on Stack Overflow;Stack Overflow f...   Daily or almost daily
# 2  Collectives on Stack Overflow;Stack Overflow;S...  Multiple times per day
# 3  Collectives on Stack Overflow;Stack Overflow f...   Daily or almost daily
# 4  Collectives on Stack Overflow;Stack Overflow f...  Multiple times per day
#
#   SOAccount              SOPartFreq           SOComm              Age Gender  \
# 0       NaN                     NaN              NaN              NaN    NaN
# 1       Yes   Daily or almost daily         Not sure              NaN    NaN
# 2       Yes  Multiple times per day          Neutral  25-34 years old    Man
# 3       Yes    A few times per week  Yes, definitely  35-44 years old    Man
# 4       Yes   Daily or almost daily  Yes, definitely  25-34 years old    NaN
#
#   Trans                Sexuality Ethnicity      Accessibility  \
# 0   NaN                      NaN       NaN                NaN
# 1   NaN                      NaN       NaN                NaN
# 2    No                 Bisexual     White  None of the above
# 3    No  Straight / Heterosexual     White  None of the above
# 4   NaN                      NaN       NaN                NaN
#
#                                         MentalHealth TBranch ICorPM  WorkExp  \
# 0                                                NaN     NaN    NaN      NaN
# 1                                                NaN      No    NaN      NaN
# 2  I have a mood or emotional disorder (e.g., dep...      No    NaN      NaN
# 3                                  None of the above      No    NaN      NaN
# 4                                                NaN      No    NaN      NaN
#
#   Knowledge_1 Knowledge_2 Knowledge_3 Knowledge_4 Knowledge_5 Knowledge_6  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Knowledge_7 Frequency_1 Frequency_2 Frequency_3 TimeSearching TimeAnswering  \
# 0         NaN         NaN         NaN         NaN           NaN           NaN
# 1         NaN         NaN         NaN         NaN           NaN           NaN
# 2         NaN         NaN         NaN         NaN           NaN           NaN
# 3         NaN         NaN         NaN         NaN           NaN           NaN
# 4         NaN         NaN         NaN         NaN           NaN           NaN
#
#   Onboarding ProfessionalTech TrueFalse_1 TrueFalse_2 TrueFalse_3  \
# 0        NaN              NaN         NaN         NaN         NaN
# 1        NaN              NaN         NaN         NaN         NaN
# 2        NaN              NaN         NaN         NaN         NaN
# 3        NaN              NaN         NaN         NaN         NaN
# 4        NaN              NaN         NaN         NaN         NaN
#
#             SurveyLength                  SurveyEase  ConvertedCompYearly
# 0                    NaN                         NaN                  NaN
# 1               Too long                   Difficult                  NaN
# 2  Appropriate in length  Neither easy nor difficult              40205.0
# 3  Appropriate in length                        Easy             215232.0
# 4               Too long                        Easy                  NaN

# %%
schema_df
# Out:
#                          qid  \
# qname
# S0                     QID16
# MetaInfo               QID12
# S1                      QID1
# MainBranch              QID2
# Employment            QID296
# RemoteWork            QID308
# CodingActivities      QID297
# S2                    QID190
# EdLevel                QID25
# LearnCode             QID276
# LearnCodeOnline       QID281
# LearnCodeCoursesCert  QID306
# YearsCode              QID32
# YearsCodePro           QID34
# DevType                QID31
# OrgSize                QID29
# PurchaseInfluence     QID278
# BuyNewTool            QID279
# Country                 QID6
# Currency               QID50
# CompTotal              QID51
# CompFreq               QID52
# S3                     QID61
# Language              QID233
# Database              QID262
# Platform              QID263
# Webframe              QID264
# MiscTech              QID265
# ToolsTech             QID275
# NEWCollabTools        QID274
# OpSys                  QID71
# VersionControlSystem  QID283
# VCInteraction         QID284
# VCHosting             QID285
# OfficeStackAsync      QID282
# OfficeStackSync       QID307
# Blockchain            QID305
# S4                     QID91
# NEWSOSites            QID266
# SOVisitFreq           QID100
# SOAccount             QID101
# SOPartFreq            QID102
# SOComm                QID106
# S5                    QID121
# Age                   QID127
# Gender                QID122
# Trans                 QID153
# Sexuality             QID136
# Ethnicity             QID126
# Accessibility         QID124
# MentalHealth          QID125
# S6                    QID295
# TBranch               QID299
# ICorPM                QID287
# WorkExp               QID288
# Knowledge             QID289
# Frequency             QID290
# TimeSearching         QID291
# TimeAnswering         QID292
# Onboarding            QID293
# ProfessionalTech      QID304
# SOTeamsUsage          QID286
# TrueFalse             QID294
# S7                    QID131
# SurveyLength          QID132
# SurveyEase            QID133
# Knowledge_1           QID289
# Knowledge_2           QID289
# Knowledge_3           QID289
# Knowledge_4           QID289
# Knowledge_5           QID289
# Knowledge_6           QID289
# Knowledge_7           QID289
# Frequency_1           QID290
# Frequency_2           QID290
# Frequency_3           QID290
# TrueFalse_1           QID294
# TrueFalse_2           QID294
# TrueFalse_3           QID294
#
#                                                                question  \
# qname
# S0                    <div><span style="font-size:19px;"><strong>Hel...
# MetaInfo                                              Browser Meta Info
# S1                    <span style="font-size:22px; font-family: aria...
# MainBranch            Which of the following options best describes ...
# Employment            Which of the following best describes your cur...
# RemoteWork            Which best describes your current work situation?
# CodingActivities      Which of the following best describes the code...
# S2                    <span style="font-size:22px; font-family: aria...
# EdLevel               Which of the following best describes the high...
# LearnCode             How did you learn to code? Select all that apply.
# LearnCodeOnline       What online resources do you use to learn to c...
# LearnCodeCoursesCert  What online courses or certifications do you u...
# YearsCode             Including any education, how many years have y...
# YearsCodePro          NOT including education, how many years have y...
# DevType               Which of the following describes your current ...
# OrgSize               Approximately how many people are employed by ...
# PurchaseInfluence     What level of influence do you, personally, ha...
# BuyNewTool            When buying a new tool or software, how do you...
# Country               Where do you live? <span style="font-weight: b...
# Currency              Which currency do you use day-to-day? If your ...
# CompTotal             What is your current total compensation (salar...
# CompFreq               Is that compensation weekly, monthly, or yearly?
# S3                    <span style="font-size:22px; font-family: aria...
# Language              Which <b>programming, scripting, and markup la...
# Database              Which <b>database environments </b>have you do...
# Platform              Which <b>cloud platforms</b> have you done ext...
# Webframe              Which <b>web frameworks and web technologies</...
# MiscTech              Which <b>other frameworks and libraries</b> ha...
# ToolsTech             Which <b>developer </b><strong>tools</strong> ...
# NEWCollabTools        Which <strong>development environments</strong...
# OpSys                 What is the primary <b>operating system</b> in...
# VersionControlSystem  What are the primary <b>version control system...
# VCInteraction         How do you interact with your version control ...
# VCHosting             What version control hosting service are you u...
# OfficeStackAsync      Which <b>collaborative work management tools</...
# OfficeStackSync       Which <b>communication tools</b> did you use r...
# Blockchain            How favorable are you about blockchain, crypto...
# S4                    <span style="font-size:22px; font-family: aria...
# NEWSOSites            Which of the following Stack Overflow sites ha...
# SOVisitFreq           How frequently would you say you visit Stack O...
# SOAccount                         Do you have a Stack Overflow account?
# SOPartFreq            How frequently would you say you participate i...
# SOComm                Do you consider yourself a member of the Stack...
# S5                    <span style="font-size:22px; font-family: aria...
# Age                                                   What is your age?
# Gender                Which of the following describe you, if any? P...
# Trans                                   Do you identify as transgender?
# Sexuality             Which of the following describe you, if any? P...
# Ethnicity             Which of the following describe you, if any? P...
# Accessibility         Which of the following describe you, if any? P...
# MentalHealth          Which of the following describe you, if any? P...
# S6                    <span style="font-size:22px; font-family: aria...
# TBranch               <span style="font-size:16px;">Would you like t...
# ICorPM                Are you an independent contributor or people m...
# WorkExp               How many years of working experience do you have?
# Knowledge             Please rate your level of agreement with the f...
# Frequency             How frequently do you experience each of the f...
# TimeSearching         On an average day, how much time do you typica...
# TimeAnswering         On an average day, how much time do you typica...
# Onboarding            The time it takes to onboard new hires at my c...
# ProfessionalTech                                        My company has:
# SOTeamsUsage               Does your team use Stack Overflow for Teams?
# TrueFalse                                         Last few questions...
# S7                    <span style="font-size:22px;"><strong>Final Qu...
# SurveyLength          How do you feel about the length of the survey...
# SurveyEase            How easy or difficult was this survey to compl...
# Knowledge_1           I have interactions with people outside of my ...
# Knowledge_2           Knowledge silos prevent me from getting ideas ...
# Knowledge_3           I can find up-to-date information within my or...
# Knowledge_4           I am able to quickly find answers to my questi...
# Knowledge_5           I know which system or resource to use to find...
# Knowledge_6           I often find myself answering questions that I...
# Knowledge_7           Waiting on answers to questions often causes i...
# Frequency_1           Needing help from people outside of your immed...
# Frequency_2           Interacting with people outside of your immedi...
# Frequency_3           Encountering knowledge silos (where one indivi...
# TrueFalse_1           Are you involved in supporting new hires durin...
# TrueFalse_2           Do you use learning resources provided by your...
# TrueFalse_3           Does your employer give you time to learn new ...
#
#                      force_resp    type selector
# qname
# S0                        False      DB       TB
# MetaInfo                  False    Meta  Browser
# S1                        False      DB       TB
# MainBranch                 True      MC     SAVR
# Employment                False      MC     MAVR
# RemoteWork                False      MC     SAVR
# CodingActivities          False      MC     MAVR
# S2                        False      DB       TB
# EdLevel                   False      MC     SAVR
# LearnCode                 False      MC     MAVR
# LearnCodeOnline           False      MC     MAVR
# LearnCodeCoursesCert      False      MC     MAVR
# YearsCode                 False      MC       DL
# YearsCodePro              False      MC       DL
# DevType                   False      MC     MAVR
# OrgSize                   False      MC     MAVR
# PurchaseInfluence         False      MC     SAVR
# BuyNewTool                False      MC     MAVR
# Country                    True      MC       DL
# Currency                   True      MC       DL
# CompTotal                 False      TE       SL
# CompFreq                  False      MC     MAVR
# S3                        False      DB       TB
# Language                  False  Matrix   Likert
# Database                  False  Matrix   Likert
# Platform                  False  Matrix   Likert
# Webframe                  False  Matrix   Likert
# MiscTech                  False  Matrix   Likert
# ToolsTech                 False  Matrix   Likert
# NEWCollabTools            False  Matrix   Likert
# OpSys                     False  Matrix   Likert
# VersionControlSystem      False      MC     MAVR
# VCInteraction             False      MC     MAVR
# VCHosting                 False  Matrix   Likert
# OfficeStackAsync          False  Matrix   Likert
# OfficeStackSync           False  Matrix   Likert
# Blockchain                False      MC     SAVR
# S4                        False      DB       TB
# NEWSOSites                False      MC     MAVR
# SOVisitFreq               False      MC     MAVR
# SOAccount                 False      MC     MAVR
# SOPartFreq                False      MC     MAVR
# SOComm                    False      MC     MAVR
# S5                        False      DB       TB
# Age                       False      MC     MAVR
# Gender                    False      MC     MAVR
# Trans                     False      MC     MAVR
# Sexuality                 False      MC     MAVR
# Ethnicity                 False      MC     MAVR
# Accessibility             False      MC     MAVR
# MentalHealth              False      MC     MAVR
# S6                        False      DB       TB
# TBranch                    True      MC     SAVR
# ICorPM                    False      MC     SAVR
# WorkExp                   False  Slider  HSLIDER
# Knowledge                 False  Matrix   Likert
# Frequency                 False  Matrix   Likert
# TimeSearching             False      MC     SAVR
# TimeAnswering             False      MC     SAVR
# Onboarding                False      MC     SAVR
# ProfessionalTech          False      MC     MAVR
# SOTeamsUsage              False      MC     SAVR
# TrueFalse                 False  Matrix   Likert
# S7                        False      DB       TB
# SurveyLength              False      MC     MAVR
# SurveyEase                False      MC     MAVR
# Knowledge_1                 NaN      MC     MAVR
# Knowledge_2                 NaN      MC     MAVR
# Knowledge_3                 NaN      MC     MAVR
# Knowledge_4                 NaN      MC     MAVR
# Knowledge_5                 NaN      MC     MAVR
# Knowledge_6                 NaN      MC     MAVR
# Knowledge_7                 NaN      MC     MAVR
# Frequency_1                 NaN      MC     MAVR
# Frequency_2                 NaN      MC     MAVR
# Frequency_3                 NaN      MC     MAVR
# TrueFalse_1                 NaN      MC     MAVR
# TrueFalse_2                 NaN      MC     MAVR
# TrueFalse_3                 NaN      MC     MAVR

# %%
schema_df.loc[0:100, ['qname','question']]
# Out:
#                    qname                                           question
# 0                     S0  <div><span style="font-size:19px;"><strong>Hel...
# 1               MetaInfo                                  Browser Meta Info
# 2                     S1  <span style="font-size:22px; font-family: aria...
# 3             MainBranch  Which of the following options best describes ...
# 4             Employment  Which of the following best describes your cur...
# 5             RemoteWork  Which best describes your current work situation?
# 6       CodingActivities  Which of the following best describes the code...
# 7                     S2  <span style="font-size:22px; font-family: aria...
# 8                EdLevel  Which of the following best describes the high...
# 9              LearnCode  How did you learn to code? Select all that apply.
# 10       LearnCodeOnline  What online resources do you use to learn to c...
# 11  LearnCodeCoursesCert  What online courses or certifications do you u...
# 12             YearsCode  Including any education, how many years have y...
# 13          YearsCodePro  NOT including education, how many years have y...
# 14               DevType  Which of the following describes your current ...
# 15               OrgSize  Approximately how many people are employed by ...
# 16     PurchaseInfluence  What level of influence do you, personally, ha...
# 17            BuyNewTool  When buying a new tool or software, how do you...
# 18               Country  Where do you live? <span style="font-weight: b...
# 19              Currency  Which currency do you use day-to-day? If your ...
# 20             CompTotal  What is your current total compensation (salar...
# 21              CompFreq   Is that compensation weekly, monthly, or yearly?
# 22                    S3  <span style="font-size:22px; font-family: aria...
# 23              Language  Which <b>programming, scripting, and markup la...
# 24              Database  Which <b>database environments </b>have you do...
# 25              Platform  Which <b>cloud platforms</b> have you done ext...
# 26              Webframe  Which <b>web frameworks and web technologies</...
# 27              MiscTech  Which <b>other frameworks and libraries</b> ha...
# 28             ToolsTech  Which <b>developer </b><strong>tools</strong> ...
# 29        NEWCollabTools  Which <strong>development environments</strong...
# 30                 OpSys  What is the primary <b>operating system</b> in...
# 31  VersionControlSystem  What are the primary <b>version control system...
# 32         VCInteraction  How do you interact with your version control ...
# 33             VCHosting  What version control hosting service are you u...
# 34      OfficeStackAsync  Which <b>collaborative work management tools</...
# 35       OfficeStackSync  Which <b>communication tools</b> did you use r...
# 36            Blockchain  How favorable are you about blockchain, crypto...
# 37                    S4  <span style="font-size:22px; font-family: aria...
# 38            NEWSOSites  Which of the following Stack Overflow sites ha...
# 39           SOVisitFreq  How frequently would you say you visit Stack O...
# 40             SOAccount              Do you have a Stack Overflow account?
# 41            SOPartFreq  How frequently would you say you participate i...
# 42                SOComm  Do you consider yourself a member of the Stack...
# 43                    S5  <span style="font-size:22px; font-family: aria...
# 44                   Age                                  What is your age?
# 45                Gender  Which of the following describe you, if any? P...
# 46                 Trans                    Do you identify as transgender?
# 47             Sexuality  Which of the following describe you, if any? P...
# 48             Ethnicity  Which of the following describe you, if any? P...
# 49         Accessibility  Which of the following describe you, if any? P...
# 50          MentalHealth  Which of the following describe you, if any? P...
# 51                    S6  <span style="font-size:22px; font-family: aria...
# 52               TBranch  <span style="font-size:16px;">Would you like t...
# 53                ICorPM  Are you an independent contributor or people m...
# 54               WorkExp  How many years of working experience do you have?
# 55             Knowledge  Please rate your level of agreement with the f...
# 56             Frequency  How frequently do you experience each of the f...
# 57         TimeSearching  On an average day, how much time do you typica...
# 58         TimeAnswering  On an average day, how much time do you typica...
# 59            Onboarding  The time it takes to onboard new hires at my c...
# 60      ProfessionalTech                                    My company has:
# 61          SOTeamsUsage       Does your team use Stack Overflow for Teams?
# 62             TrueFalse                              Last few questions...
# 63                    S7  <span style="font-size:22px;"><strong>Final Qu...
# 64          SurveyLength  How do you feel about the length of the survey...
# 65            SurveyEase  How easy or difficult was this survey to compl...
# 66           Knowledge_1  I have interactions with people outside of my ...
# 67           Knowledge_2  Knowledge silos prevent me from getting ideas ...
# 68           Knowledge_3  I can find up-to-date information within my or...
# 69           Knowledge_4  I am able to quickly find answers to my questi...
# 70           Knowledge_5  I know which system or resource to use to find...
# 71           Knowledge_6  I often find myself answering questions that I...
# 72           Knowledge_7  Waiting on answers to questions often causes i...
# 73           Frequency_1  Needing help from people outside of your immed...
# 74           Frequency_2  Interacting with people outside of your immedi...
# 75           Frequency_3  Encountering knowledge silos (where one indivi...
# 76           TrueFalse_1  Are you involved in supporting new hires durin...
# 77           TrueFalse_2  Do you use learning resources provided by your...
# 78           TrueFalse_3  Does your employer give you time to learn new ...

# %%
df[['MainBranch','CodingActivities']]
# Out:
#                                               MainBranch  \
# 0                                          None of these
# 1                         I am a developer by profession
# 2      I am not primarily a developer, but I write co...
# 3                         I am a developer by profession
# 4                         I am a developer by profession
# ...                                                  ...
# 73263                     I am a developer by profession
# 73264                     I am a developer by profession
# 73265  I am not primarily a developer, but I write co...
# 73266                     I am a developer by profession
# 73267  I used to be a developer by profession, but no...
#
#                                         CodingActivities
# 0                                                    NaN
# 1               Hobby;Contribute to open-source projects
# 2                                                  Hobby
# 3                           I don’t code outside of work
# 4                                                  Hobby
# ...                                                  ...
# 73263                            Freelance/contract work
# 73264                                              Hobby
# 73265                      Hobby;School or academic work
# 73266                                              Hobby
# 73267  Hobby;Contribute to open-source projects;Boots...
#
# [73268 rows x 2 columns]

# %%
df['MainBranch'].value_counts()
# Out:
# I am a developer by profession                                                   53507
# I am learning to code                                                             6309
# I am not primarily a developer, but I write code sometimes as part of my work     5794
# I code primarily as a hobby                                                       4865
# None of these                                                                     1497
# I used to be a developer by profession, but no longer am                          1296
# Name: MainBranch, dtype: int64

# %%
df.loc[40:50, ['Age','EdLevel','MainBranch','ConvertedCompYearly']]
# Out:
#                 Age                                            EdLevel  \
# 40  35-44 years old                Associate degree (A.A., A.S., etc.)
# 41  18-24 years old  Secondary school (e.g. American high school, G...
# 42  25-34 years old       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 43  35-44 years old  Some college/university study without earning ...
# 44  18-24 years old  Secondary school (e.g. American high school, G...
# 45  25-34 years old    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 46  18-24 years old  Secondary school (e.g. American high school, G...
# 47  25-34 years old       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 48  55-64 years old  Some college/university study without earning ...
# 49  25-34 years old  Secondary school (e.g. American high school, G...
# 50  25-34 years old    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                            MainBranch  ConvertedCompYearly
# 40                     I am a developer by profession             130000.0
# 41                     I am a developer by profession              68160.0
# 42                     I am a developer by profession                  NaN
# 43                        I code primarily as a hobby                  NaN
# 44                     I am a developer by profession                  NaN
# 45                     I am a developer by profession               5124.0
# 46                        I code primarily as a hobby                  NaN
# 47                     I am a developer by profession             135000.0
# 48                     I am a developer by profession             106644.0
# 49                     I am a developer by profession              51192.0
# 50  I am not primarily a developer, but I write co...                  NaN

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'BuyNewTool', 'Country', 'Currency',
#        'CompTotal', 'CompFreq', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysProfessional use',
#        'OpSysPersonal use', 'VersionControlSystem', 'VCInteraction',
#        'VCHostingPersonal use', 'VCHostingProfessional use',
#        'OfficeStackAsyncHaveWorkedWith', 'OfficeStackAsyncWantToWorkWith',
#        'OfficeStackSyncHaveWorkedWith', 'OfficeStackSyncWantToWorkWith',
#        'Blockchain', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
#        'SOComm', 'Age', 'Gender', 'Trans', 'Sexuality', 'Ethnicity',
#        'Accessibility', 'MentalHealth', 'TBranch', 'ICorPM', 'WorkExp',
#        'Knowledge_1', 'Knowledge_2', 'Knowledge_3', 'Knowledge_4',
#        'Knowledge_5', 'Knowledge_6', 'Knowledge_7', 'Frequency_1',
#        'Frequency_2', 'Frequency_3', 'TimeSearching', 'TimeAnswering',
#        'Onboarding', 'ProfessionalTech', 'TrueFalse_1', 'TrueFalse_2',
#        'TrueFalse_3', 'SurveyLength', 'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')
